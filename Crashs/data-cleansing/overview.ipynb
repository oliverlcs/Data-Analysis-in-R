# %%
import pandas as pd

# %%
from pathlib import Path

current_directory = Path.cwd()
print(current_directory)
# Out:
# /home/oliverlcs/All_My_Data/Eduction/Dual_Study_Program/5th_Semester/Dataanalysis_R/Data-Analysis-in-R/Crashs/data-cleansing

# %%
data = pd.read_csv("../data/Crash_Reporting_Drivers_Data.csv")
data.columns
# Out:
# <positron-console-cell-3>:1: DtypeWarning: Columns (1,9) have mixed types. Specify dtype option on import or set low_memory=False.
# Index(['Report Number', 'Local Case Number', 'Agency Name', 'ACRS Report Type',
#        'Crash Date/Time', 'Route Type', 'Road Name', 'Cross-Street Name',
#        'Off-Road Description', 'Municipality', 'Related Non-Motorist',
#        'Collision Type', 'Weather', 'Surface Condition', 'Light',
#        'Traffic Control', 'Driver Substance Abuse',
#        'Non-Motorist Substance Abuse', 'Person ID', 'Driver At Fault',
#        'Injury Severity', 'Circumstance', 'Driver Distracted By',
#        'Drivers License State', 'Vehicle ID', 'Vehicle Damage Extent',
#        'Vehicle First Impact Location', 'Vehicle Body Type',
#        'Vehicle Movement', 'Vehicle Going Dir', 'Speed Limit',
#        'Driverless Vehicle', 'Parked Vehicle', 'Vehicle Year', 'Vehicle Make',
#        'Vehicle Model', 'Latitude', 'Longitude', 'Location'],
#       dtype='object')

# %%
print("Unique Reports:", len(pd.unique(data["Report Number"])))
print("Num of all Reports", len(data["Report Number"]))

# ---
# output:
# Unique Reports: 115360
# Num of all Reports 204688
# Out:
# Unique Reports: 115360
# Num of all Reports 204688

# %%
pd.unique(data["ACRS Report Type"])
pd.unique(data["Route Type"])
pd.unique(data["Municipality"])
pd.unique(data["Related Non-Motorist"])
pd.unique(data["Collision Type"])
pd.unique(data["Weather"])
pd.unique(data["Surface Condition"])
pd.unique(data["Light"])
pd.unique(data["Traffic Control"])
pd.unique(data["Driver Substance Abuse"]) 
pd.unique(data["Driver At Fault"])
pd.unique(data["Injury Severity"]) 
pd.unique(data["Driver Distracted By"])
pd.unique(data["Vehicle Damage Extent"])
pd.unique(data["Vehicle First Impact Location"])
pd.unique(data["Vehicle Body Type"])
pd.unique(data["Vehicle Movement"]) 
pd.unique(data["Vehicle Going Dir"])
pd.unique(data["Driverless Vehicle"])
pd.unique(data["Parked Vehicle"])
# Out:
# array(['No', 'Unknown'], dtype=object)
